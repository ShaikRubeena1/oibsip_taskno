# %% [markdown]
# ## Exploratory Data Analysis on Retail Sales Data

# %%
# Importing the Libraries
# Importing Pandas library for data manupulation
import pandas as pd

# Importing Numpy library for Numeric Calculations
import numpy as np

# Importing Matplot and Seaborn libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Inorder to supress the warnings Import Filterwarnings:
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Loading the Dataset

df = pd.read_csv('retail_sales_dataset.csv')
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %% [markdown]
# **Problem Statement**
# - The goal is to perform exploratory data analysis (EDA) to uncover patterns,trends,and insights that can help the retail business make informed decisions.

# %%
# Head()---> Displays the first five rows of the data:
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
#Tail()---> Displays the last five rows of the data:
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %% [markdown]
# **Check the Size and Variable Types**

# %%
# Check the size of the Data:

df.shape
# Out:
# (1000, 9)

# %% [markdown]
# **Interpretation**: There are **1000 Rows and 9 Columns** has been presented in this Dataset

# %%
# Check the Variable Types:

df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
# Information about the data:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
# Check for Duplicate Values in the Dataset:

df.duplicated().sum()
# Out:
# 0

# %%
# Check for Null Values in the Dataset:

df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
# Descriptive Statistics:
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
# Descriptive Statistics for Numerical Columns:
df.describe(include = [np.number])
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
# Descriptive Statistics for Categorical Columns:
df.describe(include = 'object')
# Out:
#               Date Customer ID  Gender Product Category
# count         1000        1000    1000             1000
# unique         345        1000       2                3
# top     2023-05-16     CUST001  Female         Clothing
# freq            11           1     510              351

# %%
df['Product Category'].value_counts()
# Out:
# Clothing       351
# Electronics    342
# Beauty         307
# Name: Product Category, dtype: int64

# %%
df['Quantity'].value_counts()
# Out:
# 4    263
# 1    253
# 2    243
# 3    241
# Name: Quantity, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    510
# Male      490
# Name: Gender, dtype: int64

# %%
Total_Amount = df['Total Amount'].sum()
Total_Amount
# Out:
# 456000

# %%
df.drop(['Transaction ID','Customer ID'],axis=1,inplace = True)

# %%
df.head()
# Out:
#          Date  Gender  Age Product Category  Quantity  Price per Unit  \
# 0  2023-11-24    Male   34           Beauty         3              50
# 1  2023-02-27  Female   26         Clothing         2             500
# 2  2023-01-13    Male   50      Electronics         1              30
# 3  2023-05-21    Male   37         Clothing         1             500
# 4  2023-05-06    Male   30           Beauty         2              50
#
#    Total Amount
# 0           150
# 1          1000
# 2            30
# 3           500
# 4           100

# %%
# Skewness of the Data:
df.skew()
# Out:
# Age              -0.048812
# Quantity         -0.014036
# Price per Unit    0.736308
# Total Amount      1.376128
# dtype: float64

# %%
# Kurtosis of the Data:
df.kurt()
# Out:
# Age              -1.201212
# Quantity         -1.392867
# Price per Unit   -1.138996
# Total Amount      0.815031
# dtype: float64

# %%
# Covarience:
cov = df.cov()
cov


# set the plot Size:
fig,ax = plt.subplots(figsize = (10,7))

# Plot a Heatmap for the Covariance Matrix
# annot : print values in each cell
# Linewidths : Specify width of the Line and specifying the Plot
# vmin : Minimum value of the Variable
# vmax : Maximum value of the Variable
# Cmap : colour Code for the Plot
# fmt = set the Decimal place of the Annot

sns.heatmap(cov,annot = True,linewidths = 0.95,
            cmap = 'copper',fmt = '.2g')

# Display the Plot:
plt.show()

# %%
# Correlation:
corr = df.corr()
corr


# set the plot Size:
fig,ax = plt.subplots(figsize = (10,7))

# Plot a Heatmap for the Correlation Matrix
# annot : print values in each cell
# Linewidths : Specify width of the Line and specifying the Plot
# vmin : Minimum value of the Variable
# vmax : Maximum value of the Variable
# Cmap : colour Code for the Plot
# fmt = set the Decimal place of the Annot

sns.heatmap(corr,annot = True,linewidths = 0.95,
            cmap = 'gist_earth',fmt = '.2g')

# Display the Plot:
plt.show()

# %%
df.head()
# Out:
#          Date  Gender  Age Product Category  Quantity  Price per Unit  \
# 0  2023-11-24    Male   34           Beauty         3              50
# 1  2023-02-27  Female   26         Clothing         2             500
# 2  2023-01-13    Male   50      Electronics         1              30
# 3  2023-05-21    Male   37         Clothing         1             500
# 4  2023-05-06    Male   30           Beauty         2              50
#
#    Total Amount
# 0           150
# 1          1000
# 2            30
# 3           500
# 4           100

# %%
# Set the figure Size:
plt.rcParams['figure.figsize']=[5,4]

# Plotting countplot plot for Product Category
sns.countplot(data=df,x='Product Category',color='black')

# Title of the plot
plt.title('Count Plot for Product Category')

# Displays the plot
plt.show()

# %%
# Strip plot
sns.stripplot(x='Gender',y='Age',data=df)

# Set the title:
plt.title('Strip Plot for Gender and Age')

# display the title:
plt.show()

# %%
# Swarm Plot:
sns.swarmplot(x='Gender',y='Age',hue='Product Category',data=df)

# Set the title
plt.title('Swarm Plot for Gender and Age')

# Displays the plot:
plt.show()

# %%
# Barplot 
Total_Amount =df['Total Amount'].value_counts()

sns.barplot(data=df,x='Product Category',y=Total_Amount,color ='y')

# Set the title
plt.title('Bar Plot for Total Amount and Product Category')

# Display the plot
plt.show()

# %%
# Scatter Plot:

plt.scatter(x='Total Amount',y='Age',color ='g',data=df)
plt.scatter(x='Total Amount',y='Quantity',color ='b',data=df)

plt.legend()

plt.show()

# %% [markdown]
# **Interpretation**:There is no significant correlation between **Age** and **Quantity**

# %%
# Histogram
df.plot.hist(subplots = True, layout = (3,2),figsize = (10,6),
            sharex = True,sharey = False)

# to give the secified padding from the subplot:
plt.tight_layout()

# to display the plot:
plt.show()

# %%
# Calculating length of the Price per unit

TotalAmount = df['Total Amount']
len(TotalAmount)
# Out:
# 1000

# %%
# Set the figure Size:
plt.rcParams['figure.figsize']=[8,4]

# Plotting Density plot for Total Amount
sns.distplot(TotalAmount)

# Title of the plot
plt.title('Density plot for Total Amount')

# Displays the plot
plt.show()

# %%
PricePerUnit = df['Price per Unit']
len(PricePerUnit)
# Out:
# 1000

# %%
# Set the figure Size:
plt.rcParams['figure.figsize']=[8,4]

# Plotting Density plot for Total Amount
sns.distplot(PricePerUnit,hist = False)

# Title of the plot
plt.title('Density plot for Price Per Unit')

# Displays the plot
plt.show()

# %%
# Boxplot for Numerical Columns

df_numerical = df.describe(include = [np.number])
df_numerical.plot(kind = 'box',subplots = True,layout = (2,3))

# To give Specified padding from the subplots
plt.tight_layout()

# Display the Plot
plt.show()

# %%
# Violinplot 
sns.violinplot(x ='Quantity',data = df, color = 'purple')

# set the title
plt.title('Violin Plot for Quantity')

# displays the plot:
plt.show()

# %%
# Set the figure Size:
plt.rcParams['figure.figsize']=[5,4]

# Plotting Density plot for Total Amount
sns.countplot(data=df,x='Gender',color='orange')

# Title of the plot
plt.title('Count plot for Gender')

# Displays the plot
plt.show()

# %%
# Pair plot
sns.pairplot(data = df)
plt.show()
